# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn.metrics as metrics

# %%
data = pd.read_csv('C:/Users/Jagdish/Downloads/Ineuron/Assignment/KNN/nba_2013.csv')

# %%
data.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  ...  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468  ...
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503  ...
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520  ...
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459  ...
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546  ...
#
#    drb  trb  Assists  Steals  Blocks  Turnovers  Personal Fouls   pts  \
# 0  144  216       28      23      26         30             122   171
# 1  190  332       43      40      57         71             203   265
# 2  204  306       38      24      36         39             108   362
# 3  230  262      248      35       3        146             136  1330
# 4  183  277       40      23      46         63             187   328
#
#       season  Unnamed: 30
# 0  2013-2014         2013
# 1  2013-2014         2013
# ...

# %%
print(data.shape)
data.describe()
# Out:
# (481, 31)
#               age           g          gs           mp          fg  \
# count  481.000000  481.000000  481.000000   481.000000  481.000000
# mean    26.509356   53.253638   25.571726  1237.386694  192.881497
# std      4.198265   25.322711   29.658465   897.258840  171.832793
# min     19.000000    1.000000    0.000000     1.000000    0.000000
# 25%     23.000000   32.000000    0.000000   388.000000   47.000000
# 50%     26.000000   61.000000   10.000000  1141.000000  146.000000
# 75%     29.000000   76.000000   54.000000  2016.000000  307.000000
# max     39.000000   83.000000   82.000000  3122.000000  849.000000
#
#                fga         fg.         x3p        x3pa        x3p.  ...  \
# count   481.000000  479.000000  481.000000  481.000000  414.000000  ...
# mean    424.463617    0.436436   39.613306  110.130977    0.285111  ...
# std     368.850833    0.098672   50.855639  132.751732    0.157633  ...
# ...

# %%
data.isna().sum()
#NaN value in 2 feature column
# Out:
# player             0
# pos                0
# age                0
# bref_team_id       0
# g                  0
# gs                 0
# mp                 0
# fg                 0
# fga                0
# fg.                2
# x3p                0
# x3pa               0
# x3p.              67
# x2p                0
# x2pa               0
# x2p.               3
# efg.               2
# ft                 0
# fta                0
# ft.               20
# orb                0
# drb                0
# trb                0
# Assists            0
# Steals             0
# Blocks             0
# Turnovers          0
# Personal Fouls     0
# pts                0
# season             0
# Unnamed: 30        0
# dtype: int64

# %%
#Replace NaN value with zero
data=data.fillna(0)
data.isna().sum()
# Out:
# player            0
# pos               0
# age               0
# bref_team_id      0
# g                 0
# gs                0
# mp                0
# fg                0
# fga               0
# fg.               0
# x3p               0
# x3pa              0
# x3p.              0
# x2p               0
# x2pa              0
# x2p.              0
# efg.              0
# ft                0
# fta               0
# ft.               0
# orb               0
# drb               0
# trb               0
# Assists           0
# Steals            0
# Blocks            0
# Turnovers         0
# Personal Fouls    0
# pts               0
# season            0
# Unnamed: 30       0
# dtype: int64

# %%
data_corr = data.corr()
data_corr[data_corr.values>0.8]
# Out:
# C:\Users\Jagdish\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in greater
#           age         g        gs        mp        fg       fga       fg.  \
# age  1.000000 -0.012074  0.025163  0.007961 -0.009749 -0.018304  0.017929
# g   -0.012074  1.000000  0.610951  0.864487  0.739993  0.746963  0.342499
# g   -0.012074  1.000000  0.610951  0.864487  0.739993  0.746963  0.342499
# g   -0.012074  1.000000  0.610951  0.864487  0.739993  0.746963  0.342499
# gs   0.025163  0.610951  1.000000  0.860036  0.821619  0.811531  0.240620
# ..        ...       ...       ...       ...       ...       ...       ...
# pts -0.011910  0.728462  0.810294  0.927464  0.992041  0.989211  0.257634
# pts -0.011910  0.728462  0.810294  0.927464  0.992041  0.989211  0.257634
# pts -0.011910  0.728462  0.810294  0.927464  0.992041  0.989211  0.257634
# pts -0.011910  0.728462  0.810294  0.927464  0.992041  0.989211  0.257634
# ...

# %%
data.dtypes[data.dtypes == object]
# Out:
# player          object
# pos             object
# bref_team_id    object
# season          object
# dtype: object

# %%
#We have 4 object features
data[['player','pos','bref_team_id','season']]
# Out:
#              player pos bref_team_id     season
# 0        Quincy Acy  SF          TOT  2013-2014
# 1      Steven Adams   C          OKC  2013-2014
# 2       Jeff Adrien  PF          TOT  2013-2014
# 3     Arron Afflalo  SG          ORL  2013-2014
# 4     Alexis Ajinca   C          NOP  2013-2014
# ..              ...  ..          ...        ...
# 476     Tony Wroten  SG          PHI  2013-2014
# 477      Nick Young  SG          LAL  2013-2014
# 478  Thaddeus Young  PF          PHI  2013-2014
# 479     Cody Zeller   C          CHA  2013-2014
# 480    Tyler Zeller   C          CLE  2013-2014
#
# [481 rows x 4 columns]

# %%
print('unique team id',data['bref_team_id'].unique())
print('-'*50)
print('unique value in pos',data['pos'].unique())
# Out:
# unique team id ['TOT' 'OKC' 'ORL' 'NOP' 'NYK' 'POR' 'MIA' 'MEM' 'BRK' 'PHI' 'MIL' 'ATL'
#  'WAS' 'GSW' 'DEN' 'HOU' 'SAS' 'BOS' 'PHO' 'MIN' 'LAC' 'CLE' 'UTA' 'DET'
#  'CHA' 'DAL' 'CHI' 'LAL' 'IND' 'TOR' 'SAC']
# --------------------------------------------------
# unique value in pos ['SF' 'C' 'PF' 'SG' 'PG' 'G' 'F']

# %%
data.columns
# Out:
# Index(['player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp', 'fg', 'fga',
#        'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft',
#        'fta', 'ft.', 'orb', 'drb', 'trb', 'Assists', 'Steals', 'Blocks',
#        'Turnovers', 'Personal Fouls', 'pts', 'season', 'Unnamed: 30'],
#       dtype='object')

# %%
x_columns = data[['age', 'g', 'gs', 'mp', 'fg', 'fga',
       'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft',
       'fta', 'ft.', 'orb', 'drb', 'trb', 'Assists', 'Steals', 'Blocks',
       'Turnovers', 'Personal Fouls',]]

y_columns = data['pts']

# %%
x_columns.shape
y_columns.shape
# Out:
# (481,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_columns,y_columns, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
y_pred = knn.predict(x_test)

# %%
knn.score(x_test,y_test)
# Out:
# 0.9674421126682651

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x_columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_columns,y_columns, test_size=0.25)
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=8)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                     weights='uniform')

# %%
y_pred = knn.predict(x_test)

# %%
knn.score(x_test,y_test)
# Out:
# 0.972150588558901

# %%
mse = (((y_pred - y_test) ** 2).sum()) / len(y_pred)
mse
# Out:
# 5728.747417355372

# %%
print ("Mean Squared Error is:", format(metrics.mean_squared_error(y_test, y_pred), '.7f'))
print ("Regression score is:", format(metrics.r2_score(y_test, y_pred),'.4f'))
# Out:
# Mean Squared Error is: 5728.7474174
# Regression score is: 0.9722

# %%
Test_With_Predicted = pd.DataFrame({'Actual Points': y_test.tolist(), 'Predicted Points': y_pred.tolist()})

Test_With_Predicted
# Out:
#      Actual Points  Predicted Points
# 0              339           341.500
# 1              280           342.875
# 2              419           464.750
# 3               20            13.000
# 4              915           811.375
# ..             ...               ...
# 116            298           364.750
# 117            820           791.500
# 118            457           395.875
# 119            754           699.500
# 120            347           347.875
#
# [121 rows x 2 columns]
